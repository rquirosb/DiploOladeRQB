# %% [markdown]
# # Informe de aportes hidrologicos para el año 2004

# %% [markdown]
# Este es un ejemplo de **clase** para *manipulación* de **_archivos_** csv usando python
# + item 1
# + item 2
# + item 3

# %%
help (open)
# Out:
# Help on built-in function open in module io:
#
# open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)
#     Open file and return a stream.  Raise IOError upon failure.
#
#     file is either a text or byte string giving the name (and the path
#     if the file isn't in the current working directory) of the file to
#     be opened or an integer file descriptor of the file to be
#     wrapped. (If a file descriptor is given, it is closed when the
#     returned I/O object is closed, unless closefd is set to False.)
#
#     mode is an optional string that specifies the mode in which the file
#     is opened. It defaults to 'r' which means open for reading in text
#     mode.  Other common values are 'w' for writing (truncating the file if
#     it already exists), 'x' for creating and writing to a new file, and
#     'a' for appending (which on some Unix systems, means that all writes
# ...

# %%
# %load Demo.txt
este es un archivo par el curso de python que tanto me está costando, es algo muy complicado pero ahí vamos

# %%
# %%writefile demo2.txt
# returns a file object whose type depends on the mode, and through which the standard file operations such as reading and writing are performed.
# Out:
# Writing demo2.txt

# %%
# %ls
# Out:
# AportesDiario_2004.csv  Dropbox/                Pictures/
# Box Sync/               Google Drive/           Public/
# Demo.txt                Informe2004.ipynb       Sites/
# Desktop/                Library/                anaconda/
# Documents/              Movies/                 demo1.txt
# Downloads/              Music/                  demo2.txt

# %%
# %load demo2.txt
returns a file object whose type depends on the mode, and through which the standard file operations such as reading and writing are performed.

# %%
# !head AportesDiario_2004.csv
# Out:
# ;;;;;
# Historico Aportes Diario 2004;;;;;
# ;;;;;
# Fecha;Region Hidrologica;Nombre R�o;Aportes Caudal m3/s;Aportes Energ�a kWh;Aportes %
# 2004-01-01;ANTIOQUIA;A. SAN LORENZO;17,56;3.910.000,00;72,27%
# 2004-01-01;ANTIOQUIA;CONCEPCION;6,15;1.385.300,00;123,69%
# 2004-01-01;ANTIOQUIA;DESV. EEPPM (NEC,PAJ,DOL);11,43;2.574.700,00;147,13%
# 2004-01-01;ANTIOQUIA;GRANDE;18,65;4.563.500,00;79,23%
# 2004-01-01;ANTIOQUIA;GUADALUPE;11,28;2.540.900,00;80,15%
# 2004-01-01;ANTIOQUIA;GUATAPE;32,71;5.405.100,00;141,49%

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-af55e7023913> in <module>()
# ----> 1 import pandas as pd
#
# ImportError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
pd.read_csv('AportesDiario_2004.csv', sep=';', decimal=',', thousands='.', skiprows=3)
# Out:
#            Fecha Region Hidrologica                 Nombre Rio  \
# 0     2004-01-01          ANTIOQUIA             A. SAN LORENZO
# 1     2004-01-01          ANTIOQUIA                 CONCEPCION
# 2     2004-01-01          ANTIOQUIA  DESV. EEPPM (NEC,PAJ,DOL)
# 3     2004-01-01          ANTIOQUIA                     GRANDE
# 4     2004-01-01          ANTIOQUIA                  GUADALUPE
# 5     2004-01-01          ANTIOQUIA                    GUATAPE
# 6     2004-01-01          ANTIOQUIA                     MIEL I
# 7     2004-01-01          ANTIOQUIA                       NARE
# 8     2004-01-01          ANTIOQUIA                   PORCE II
# 9     2004-01-01          ANTIOQUIA                 SAN CARLOS
# 10    2004-01-01          ANTIOQUIA                     TENCHE
# 11    2004-01-01             CARIBE                  SINU URRA
# 12    2004-01-01             CENTRO                BOGOTA N.R.
# 13    2004-01-01             CENTRO          MAGDALENA BETANIA
# ...

# %%
x = pd.read_csv('AportesDiario_2004.csv', sep=';', decimal=',', thousands='.', skiprows=3)

# %%
x.head()
# Out:
#         Fecha Region Hidrologica                 Nombre Rio  \
# 0  2004-01-01          ANTIOQUIA             A. SAN LORENZO
# 1  2004-01-01          ANTIOQUIA                 CONCEPCION
# 2  2004-01-01          ANTIOQUIA  DESV. EEPPM (NEC,PAJ,DOL)
# 3  2004-01-01          ANTIOQUIA                     GRANDE
# 4  2004-01-01          ANTIOQUIA                  GUADALUPE
#
#    Aportes Caudal m3/s  Aportes Energia kWh Aportes %
# 0                17.56            3910000.0    72,27%
# 1                 6.15            1385300.0   123,69%
# 2                11.43            2574700.0   147,13%
# 3                18.65            4563500.0    79,23%
# 4                11.28            2540900.0    80,15%

# %%
x
# Out:
#            Fecha Region Hidrologica                 Nombre Rio  \
# 0     2004-01-01          ANTIOQUIA             A. SAN LORENZO
# 1     2004-01-01          ANTIOQUIA                 CONCEPCION
# 2     2004-01-01          ANTIOQUIA  DESV. EEPPM (NEC,PAJ,DOL)
# 3     2004-01-01          ANTIOQUIA                     GRANDE
# 4     2004-01-01          ANTIOQUIA                  GUADALUPE
# 5     2004-01-01          ANTIOQUIA                    GUATAPE
# 6     2004-01-01          ANTIOQUIA                     MIEL I
# 7     2004-01-01          ANTIOQUIA                       NARE
# 8     2004-01-01          ANTIOQUIA                   PORCE II
# 9     2004-01-01          ANTIOQUIA                 SAN CARLOS
# 10    2004-01-01          ANTIOQUIA                     TENCHE
# 11    2004-01-01             CARIBE                  SINU URRA
# 12    2004-01-01             CENTRO                BOGOTA N.R.
# 13    2004-01-01             CENTRO          MAGDALENA BETANIA
# ...

# %%
x['Fecha']
# Out:
# 0       2004-01-01
# 1       2004-01-01
# 2       2004-01-01
# 3       2004-01-01
# 4       2004-01-01
# 5       2004-01-01
# 6       2004-01-01
# 7       2004-01-01
# 8       2004-01-01
# 9       2004-01-01
# 10      2004-01-01
# 11      2004-01-01
# 12      2004-01-01
# 13      2004-01-01
# 14      2004-01-01
# 15      2004-01-01
# 16      2004-01-01
# 17      2004-01-01
# 18      2004-01-01
# 19      2004-01-01
# 20      2004-01-01
# 21      2004-01-01
# 22      2004-01-01
# 23      2004-01-01
# 24      2004-01-02
# 25      2004-01-02
# 26      2004-01-02
# 27      2004-01-02
# 28      2004-01-02
# 29      2004-01-02
#            ...
# 8756    2004-12-30
# 8757    2004-12-30
# 8758    2004-12-30
# 8759    2004-12-30
# 8760    2004-12-31
# 8761    2004-12-31
# 8762    2004-12-31
# 8763    2004-12-31
# 8764    2004-12-31
# 8765    2004-12-31
# 8766    2004-12-31
# 8767    2004-12-31
# 8768    2004-12-31
# 8769    2004-12-31
# 8770    2004-12-31
# 8771    2004-12-31
# ...

# %%
x['Region Hidrologica']
# Out:
# 0            ANTIOQUIA
# 1            ANTIOQUIA
# 2            ANTIOQUIA
# 3            ANTIOQUIA
# 4            ANTIOQUIA
# 5            ANTIOQUIA
# 6            ANTIOQUIA
# 7            ANTIOQUIA
# 8            ANTIOQUIA
# 9            ANTIOQUIA
# 10           ANTIOQUIA
# 11              CARIBE
# 12              CENTRO
# 13              CENTRO
# 14              CENTRO
# 15             ORIENTE
# 16             ORIENTE
# 17             ORIENTE
# 18      RIOS ESTIMADOS
# 19               VALLE
# 20               VALLE
# 21               VALLE
# 22               VALLE
# 23               VALLE
# 24           ANTIOQUIA
# 25           ANTIOQUIA
# 26           ANTIOQUIA
# 27           ANTIOQUIA
# 28           ANTIOQUIA
# 29           ANTIOQUIA
#              ...
# 8756             VALLE
# 8757             VALLE
# 8758             VALLE
# 8759             VALLE
# 8760         ANTIOQUIA
# 8761         ANTIOQUIA
# 8762         ANTIOQUIA
# 8763         ANTIOQUIA
# 8764         ANTIOQUIA
# ...

# %%
len(x[x['Region Hidrologica'] == 'ANTIOQUIA'])
# Out:
# 4026

# %%
import statistics

# %%
statistics.mean (x[x['Nombre Rio'] == ['Aportes Energia kWh']).values[:]))
# Out:
#   File "<ipython-input-38-96bd5a55dc84>", line 1
#     statistics.mean (x[x['Nombre Rio'] == 'Guadalupe'['Aportes Energia kWh']).values[:]))
#                                                                             ^
# SyntaxError: invalid syntax

# %%
n = set (x['Nombre Rio'])
n
# Out:
# {nan,
#  'ALTOANCHICAYA',
#  'A. SAN LORENZO',
#  'PORCE II',
#  'CALIMA',
#  'GRANDE',
#  'OTROS RIOS (ESTIMADOS)',
#  'CONCEPCION',
#  'DESV. EEPPM (NEC,PAJ,DOL)',
#  'BOGOTA N.R.',
#  'MAGDALENA BETANIA',
#  'TENCHE',
#  'CHUZA',
#  'PRADO',
#  'GUATAPE',
#  'GUADALUPE',
#  'SINU URRA',
#  'NARE',
#  'DIGUA',
#  'CAUCA SALVAJINA',
#  'FLORIDA II',
#  'SAN CARLOS',
#  'MIEL I',
#  'GUAVIO',
#  'BATA'}

# %%
for y in n:
    z=x[x['Nombre Rio'] == y] ['Aportes Energia kWh']
    if len(z) > 0:
        print (y, statistics.mean(x[x['Nombre Rio'] == y] ['Aportes Energia kWh'].values[:]))
# Out:
# ALTOANCHICAYA 4620595.90164
# A. SAN LORENZO 8105399.72678
# PORCE II 4976887.15847
# CALIMA 556011.748634
# GRANDE 6729973.22404
# OTROS RIOS (ESTIMADOS) 3700456.8306
# CONCEPCION 1488170.4918
# DESV. EEPPM (NEC,PAJ,DOL) nan
# BOGOTA N.R. nan
# MAGDALENA BETANIA 5580630.32787
# TENCHE 878668.306011
# CHUZA nan
# PRADO 498419.125683
# GUATAPE 5624479.23497
# GUADALUPE 4542910.92896
# SINU URRA 3165074.04372
# NARE 17388083.6066
# DIGUA 429995.355191
# CAUCA SALVAJINA 2519614.48087
# FLORIDA II nan
# SAN CARLOS 3084508.74317
# MIEL I 3430428.4153
# GUAVIO 20624689.3443
# BATA 15712428.4153

# %%
for y in n:
    z=x[x['Nombre Rio'] == y] ['Aportes Energia kWh']
    if len(z) > 0:
        print (y, statistics.mean(x[x['Nombre Rio'] == y] ['Aportes Caudal m3/s'].values[:]))
# Out:
# ALTOANCHICAYA 43.468715847
# A. SAN LORENZO 36.4666120219
# PORCE II 99.2926502732
# CALIMA 11.9220765027
# GRANDE 27.5119672131
# OTROS RIOS (ESTIMADOS) nan
# CONCEPCION 6.60666666667
# DESV. EEPPM (NEC,PAJ,DOL) 8.31224043716
# BOGOTA N.R. 28.0518032787
# MAGDALENA BETANIA 374.490765027
# TENCHE 3.90087431694
# CHUZA 9.7424863388
# PRADO 45.5972677596
# GUATAPE 34.1030327869
# GUADALUPE 20.1679781421
# SINU URRA 284.44420765
# NARE 49.7116120219
# DIGUA 27.5295355191
# CAUCA SALVAJINA 113.523306011
# FLORIDA II 10.7124863388
# SAN CARLOS 24.9104918033
# MIEL I 78.4332513661
# GUAVIO 85.8845628415
# BATA 95.478989071

# %%
ALTOANCHICAYA 43.468715847
A. SAN LORENZO 36.4666120219
PORCE II 99.2926502732
CALIMA 11.9220765027
GRANDE 27.5119672131
OTROS RIOS (ESTIMADOS) nan
CONCEPCION 6.60666666667
DESV. EEPPM (NEC,PAJ,DOL) 8.31224043716
BOGOTA N.R. 28.0518032787
MAGDALENA BETANIA 374.490765027
TENCHE 3.90087431694
CHUZA 9.7424863388
PRADO 45.5972677596
GUATAPE 34.1030327869
GUADALUPE 20.1679781421
SINU URRA 284.44420765
NARE 49.7116120219
DIGUA 27.5295355191
CAUCA SALVAJINA 113.523306011
FLORIDA II 10.7124863388
SAN CARLOS 24.9104918033
MIEL I 78.4332513661
GUAVIO 85.8845628415
BATA 95.478989071
